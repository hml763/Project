# %%
import socket 


HOST = '127.0.0.1'
PORT = 9999

client_socket = socket.socket(socket.AF_INET,socket.SOCK_STREAM) 

client_socket.connect((HOST, PORT)) 

num = 0

# 키보드로 입력한 문자열을 서버로 전송하고 

# 서버에서 에코되어 돌아오는 메시지를 받으면 화면에 출력합니다. 

# quit를 입력할 때 까지 반복합니다. 
while True: 
    num = num + 1
    message = num
    if message == 100:
        break

    client_socket.send( repr(message).encode()) 
    data = client_socket.recv(1024) 

    print('Received from the server :',repr(data.decode())) 


client_socket.close()
# Out:
# Received from the server : '1'
# Received from the server : '2'
# Received from the server : '3'
# Received from the server : '4'
# Received from the server : '5'
# Received from the server : '6'
# Received from the server : '7'
# Received from the server : '8'
# Received from the server : '9'
# Received from the server : '10'
# Received from the server : '11'
# Received from the server : '12'
# Received from the server : '13'
# Received from the server : '14'
# Received from the server : '15'
# Received from the server : '16'
# Received from the server : '17'
# Received from the server : '18'
# Received from the server : '19'
# Received from the server : '20'
# Received from the server : '21'
# Received from the server : '22'
# Received from the server : '23'
# Received from the server : '24'
# Received from the server : '25'
# Received from the server : '26'
# Received from the server : '27'
# Received from the server : '28'
# Received from the server : '29'
# Received from the server : '30'
# Received from the server : '31'
# Received from the server : '32'
# Received from the server : '33'
# Received from the server : '34'
# Received from the server : '35'
# Received from the server : '36'
# Received from the server : '37'
# Received from the server : '38'
# Received from the server : '39'
# Received from the server : '40'
# Received from the server : '41'
# Received from the server : '42'
# Received from the server : '43'
# Received from the server : '44'
# Received from the server : '45'
# Received from the server : '46'
# Received from the server : '47'
# Received from the server : '48'
# Received from the server : '49'
# Received from the server : '50'
# Received from the server : '51'
# Received from the server : '52'
# Received from the server : '53'
# Received from the server : '54'
# Received from the server : '55'
# Received from the server : '56'
# Received from the server : '57'
# Received from the server : '58'
# Received from the server : '59'
# Received from the server : '60'
# Received from the server : '61'
# Received from the server : '62'
# Received from the server : '63'
# Received from the server : '64'
# Received from the server : '65'
# Received from the server : '66'
# Received from the server : '67'
# Received from the server : '68'
# Received from the server : '69'
# Received from the server : '70'
# Received from the server : '71'
# Received from the server : '72'
# Received from the server : '73'
# Received from the server : '74'
# Received from the server : '75'
# Received from the server : '76'
# Received from the server : '77'
# Received from the server : '78'
# Received from the server : '79'
# Received from the server : '80'
# Received from the server : '81'
# Received from the server : '82'
# Received from the server : '83'
# Received from the server : '84'
# Received from the server : '85'
# Received from the server : '86'
# Received from the server : '87'
# Received from the server : '88'
# Received from the server : '89'
# Received from the server : '90'
# Received from the server : '91'
# Received from the server : '92'
# Received from the server : '93'
# Received from the server : '94'
# Received from the server : '95'
# Received from the server : '96'
# Received from the server : '97'
# Received from the server : '98'
# Received from the server : '99'

# %%
sys.argv[0]

# %%
import socket 


HOST = '127.0.0.1'
PORT = 9999

client_socket = socket.socket(socket.AF_INET,socket.SOCK_STREAM) 

client_socket.connect((HOST, PORT)) 



# 키보드로 입력한 문자열을 서버로 전송하고 

# 서버에서 에코되어 돌아오는 메시지를 받으면 화면에 출력합니다. 

# quit를 입력할 때 까지 반복합니다. 
while True: 

    message = input('Enter Message : ')
    if message == 'quit':
    	break

    client_socket.send(message.encode()) 
    data = client_socket.recv(1024) 

    print('Received from the server :',repr(data.decode())) 


client_socket.close()
# Out:
# Enter Message : tt
# Received from the server : 'tt'
# Enter Message : dfdf
# Received from the server : 'dfdf'
# Enter Message : dsf
# Received from the server : 'dsf'
