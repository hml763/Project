# %%
from sklearn import preprocessing
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Total_datas_new = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/실험데이터/Total_datas_with_merged.csv')
Total_labels_new = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/실험데이터/Total_labels_with_merged.csv')
len(Total_datas_new), len(Total_labels_new)
# Out:
# (373395, 373395)

# %%
X_train, X_test, y_train, y_test = train_test_split(Total_datas_new, Total_labels_new, test_size=0.3, random_state=50)

model = GaussianNB()

# Train the model using the training sets
model.fit(X_train,y_train)
# Out:
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred=model.predict(X_test)

# %%
print("훈련 세트 정확도: {:.3f}".format(model.score(X_train, y_train)))
print("테스트 세트 정확도: {:.3f}".format(model.score(X_test, y_test)))
print("테스트 세트 정확도: {:.3f}".format(model.score(y_test,y_pred)))
# Out:
# 훈련 세트 정확도: 0.445
# 테스트 세트 정확도: 0.443
# 테스트 세트 정확도: 0.183

# %%
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.44257670573741953

# %%
test_size_list = [ 0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1]
accuracies=[]

for i in test_size_list:
    X_train, X_test, y_train, y_test = train_test_split(Total_datas_new, Total_labels_new, test_size=i, random_state=50)
    model = GaussianNB()
    model.fit(X_train,y_train)
    accuracies.append(model.score(X_test, y_test))

plt.plot(test_size_list, accuracies)
plt.xlabel("random_state_list")
plt.ylabel("validation accuracy")
plt.title("Accuracy Graph")
plt.show()
# Out:
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import BernoulliNB

# %%
bnb = BernoulliNB()
bnb.fit(X_train, y_train)
# Out:
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
y_pred_bnb = bnb.predict(X_test)

# %%
print("훈련 세트 정확도: {:.3f}".format(bnb.score(X_train, y_train)))
print("테스트 세트 정확도: {:.3f}".format(bnb.score(X_test, y_test)))
# Out:
# 훈련 세트 정확도: 0.453
# 테스트 세트 정확도: 0.000

# %%
print("Accuracy:", metrics.accuracy_score(y_test, y_pred_bnb))
# Out:
# Accuracy: 0.0

# %%
test_size_list = [ 0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1]
accuracies=[]

for i in test_size_list:
    X_train, X_test, y_train, y_test = train_test_split(Total_datas_new, Total_labels_new, test_size=i, random_state=50)
    bnb1 = BernoulliNB()
    bnb1.fit(X_train, y_train)
    accuracies.append(model.score(X_test, y_test))

plt.plot(test_size_list, accuracies)
plt.xlabel("random_state_list")
plt.ylabel("validation accuracy")
plt.title("Accuracy Graph")
plt.show()
# Out:
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
Total_datas
# Out:
#         -0.006162  0.065109
# 0       -0.006465  0.065312
# 1       -0.006610  0.065593
# 2       -0.006612  0.065929
# 3       -0.006487  0.066300
# 4       -0.006286  0.066686
# 5       -0.006136  0.067069
# 6       -0.006143  0.067430
# 7       -0.006328  0.067752
# 8       -0.006667  0.068019
# 9       -0.007139  0.068221
# 10      -0.007725  0.068371
# 11      -0.008366  0.068546
# 12      -0.008934  0.068829
# 13      -0.009318  0.069243
# 14      -0.009495  0.069766
# 15      -0.009485  0.070368
# 16      -0.009307  0.071022
# 17      -0.008982  0.071703
# 18      -0.008528  0.072391
# 19      -0.007963  0.073067
# 20      -0.007300  0.073686
# 21      -0.006565  0.074145
# 22      -0.005794  0.074357
# 23      -0.005022  0.074301
# 24      -0.004261  0.073990
# 25      -0.003516  0.073438
# 26      -0.002790  0.072660
# 27      -0.002087  0.071761
# 28      -0.001392  0.071014
# 29      -0.000648  0.070663
# ...           ...       ...
# 373369   0.113334  0.059054
# ...

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
mlb_Total_datas = Total_datas
(mlb_Total_datas)
# Out:
#         -0.006162  0.065109
# 0        0.993535  0.065312
# 1        0.993390  0.065593
# 2        0.993388  0.065929
# 3        0.993513  0.066300
# 4        0.993714  0.066686
# 5        0.993864  0.067069
# 6        0.993857  0.067430
# 7        0.993672  0.067752
# 8        0.993333  0.068019
# 9        0.992861  0.068221
# 10       0.992275  0.068371
# 11       0.991634  0.068546
# 12       0.991066  0.068829
# 13       0.990682  0.069243
# 14       0.990505  0.069766
# 15       0.990515  0.070368
# 16       0.990693  0.071022
# 17       0.991018  0.071703
# 18       0.991472  0.072391
# 19       0.992037  0.073067
# 20       0.992700  0.073686
# 21       0.993435  0.074145
# 22       0.994206  0.074357
# 23       0.994978  0.074301
# 24       0.995739  0.073990
# 25       0.996484  0.073438
# 26       0.997210  0.072660
# 27       0.997913  0.071761
# 28       0.998608  0.071014
# 29       0.999352  0.070663
# ...           ...       ...
# 373369   0.113334  0.059054
# ...

# %%
mlb_Total_datas = Total_datas
(mlb_Total_datas.iloc[0])
# Out:
# -0.006162    0.993535
# 0.065109     0.065312
# Name: 0, dtype: float64

# %%
for k in range(len(mlb_Total_datas)):
    for j in range(2):
        if(mlb_Total_datas.iloc[k][j] < 0):
            mlb_Total_datas.iloc[k][j] = mlb_Total_datas.iloc[k][j] + 1

# %%
mlb_X_train, mlb_X_test, mlb_y_train, mlb_y_test = train_test_split(mlb_Total_datas, Total_labels, test_size=i, random_state=50)

# %%
mlb = MultinomialNB()
mlb.fit(mlb_X_train, mlb_y_train)
# Out:
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_pred_mlb = mlb.predict(mlb_X_test)

# %%
print("훈련 세트 정확도: {:.3f}".format(mlb.score(mlb_X_train, mlb_y_train)))
print("테스트 세트 정확도: {:.3f}".format(mlb.score(mlb_X_test, mlb_y_test)))
# Out:
# 훈련 세트 정확도: 0.376
# 테스트 세트 정확도: 0.000

# %%
print("Accuracy:", metrics.accuracy_score(mlb_y_test, y_pred_mlb))
# Out:
# Accuracy: 0.0
