# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame as df
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import warnings
from sklearn.utils.testing import all_estimators

# %%
Total_datas_only = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/eps/A-B1 - A-B2   C-D1 - C-D2 데이터/merge_datas_confirm.csv')
Total_labels_only =  pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/eps/A-B1 - A-B2   C-D1 - C-D2 데이터/merge_labels_confirm.csv')

Total_datas = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/eps/A-B1 - A-B2   C-D1 - C-D2 데이터/Total_datas_with_merged.csv')
Total_labels =  pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/eps/A-B1 - A-B2   C-D1 - C-D2 데이터/Total_labels_with_merged.csv')

# %%
X_train, X_test, y_train, y_test = train_test_split(Total_datas, Total_labels, test_size=0.3, shuffle=True)

X_train1, X_test1, y_train1, y_test1 = train_test_split(Total_datas_only, Total_labels_only, test_size=0.3, shuffle=True)

# %%
all_al = np.arange(100)
all_al
all_al1 = np.arange(100)

# %%
#9:50
from scipy.sparse import csc_matrix
from sklearn.utils.testing import all_estimators
import random
i=0
for name, Clf in all_estimators(type_filter='classifier'):
    warnings.filterwarnings('ignore')
    try:
        clf = Clf()
        warnings.filterwarnings('ignore')
        clf.fit(X_train,y_train)
        y_pred = clf.predict(X_test)
        print(name, "모델의 테스트 세트 정확도: ", accuracy_score(y_test, y_pred))
        all_al[i] = accuracy_score(y_test, y_pred)
        i = i+1
    except:
        pass
# Out:
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\linear_assignment_.py:21: DeprecationWarning: The linear_assignment_ module is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   DeprecationWarning)
# AdaBoostClassifier 모델의 테스트 세트 정확도:  0.5833028325551916
# BaggingClassifier 모델의 테스트 세트 정확도:  0.8650407520152831
# BernoulliNB 모델의 테스트 세트 정확도:  0.45254822842553494
# CalibratedClassifierCV 모델의 테스트 세트 정확도:  0.35369892607504083
# ...

# %%
from scipy.sparse import csc_matrix
from sklearn.utils.testing import all_estimators
import random
i=0
for name, Clf in all_estimators(type_filter='classifier'):
    warnings.filterwarnings('ignore')
    try:
        clf = Clf()
        warnings.filterwarnings('ignore')
        clf.fit(X_train,y_train)
        y_pred = clf.predict(X_test)
        print(name, "모델의 테스트 세트 정확도: ", accuracy_score(y_test, y_pred))
        all_al[i] = accuracy_score(y_test, y_pred)
        i = i+1
    except:
        pass
# Out:
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\linear_assignment_.py:21: DeprecationWarning: The linear_assignment_ module is deprecated in 0.21 and will be removed from 0.23. Use scipy.optimize.linear_sum_assignment instead.
#   DeprecationWarning)
# AdaBoostClassifier 모델의 테스트 세트 정확도:  0.6070220230496612
# BaggingClassifier 모델의 테스트 세트 정확도:  0.8671207563002705
# BernoulliNB 모델의 테스트 세트 정확도:  0.4525035931404494
# CalibratedClassifierCV 모델의 테스트 세트 정확도:  0.35277943920227817
# ...

# %%
#9:50
from scipy.sparse import csc_matrix
from sklearn.utils.testing import all_estimators
import random
i=0

for name, Clf in all_estimators(type_filter='classifier'):
    warnings.filterwarnings('ignore')
    try:
        clf1 = Clf()
        warnings.filterwarnings('ignore')
        clf1.fit(X_train1,y_train1)
        y_pred1 = clf.predict(X_test1)
        print(name, "모델의 테스트 세트 정확도: ", accuracy_score(y_test1, y_pred1))
        all_al1[i] = accuracy_score(y_test1, y_pred1)
    except:
        pass
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# AdaBoostClassifier 모델의 테스트 세트 정확도:  0.5686216747009463
# BaggingClassifier 모델의 테스트 세트 정확도:  0.6755311551508659
# BernoulliNB 모델의 테스트 세트 정확도:  0.4540885556150687
# CalibratedClassifierCV 모델의 테스트 세트 정확도:  0.3532672737011248
# CategoricalNB 모델의 테스트 세트 정확도:  0.37635243706480986
# CheckingClassifier 모델의 테스트 세트 정확도:  0.15005356186395286
# DecisionTreeClassifier 모델의 테스트 세트 정확도:  0.633494018925192
# DummyClassifier 모델의 테스트 세트 정확도:  0.2788073558293162
# ExtraTreeClassifier 모델의 테스트 세트 정확도:  0.6324227816461346
# ...

# %%
#warnings.filterwarnings('ignore')
allAlgorithms = all_estimators(type_filter="classifier")

# %%
for name, algorithm in allAlgorithms:
    if hasattr(algorithm, 'predict_proba'):
        clf = algorithm()
        clf.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-98cfa4440c2a> in <module>
#       1 for name, algorithm in allAlgorithms:
#       2     if hasattr(algorithm, 'predict_proba'):
# ----> 3         clf = algorithm()
#       4         clf.fit(X_train,y_train)
#
# TypeError: __init__() missing 1 required positional argument: 'base_estimator'

# %%
for name, clf in all_estimators(type_filter='classifier'):
    if hasattr(clf, 'predict_proba'):
        print(clf, name)
# Out:
# <class 'sklearn.ensemble.weight_boosting.AdaBoostClassifier'> AdaBoostClassifier
# <class 'sklearn.ensemble.bagging.BaggingClassifier'> BaggingClassifier
# <class 'sklearn.naive_bayes.BernoulliNB'> BernoulliNB
# <class 'sklearn.calibration.CalibratedClassifierCV'> CalibratedClassifierCV
# <class 'sklearn.multioutput.ClassifierChain'> ClassifierChain
# <class 'sklearn.naive_bayes.ComplementNB'> ComplementNB
# <class 'sklearn.tree.tree.DecisionTreeClassifier'> DecisionTreeClassifier
# <class 'sklearn.dummy.DummyClassifier'> DummyClassifier
# <class 'sklearn.tree.tree.ExtraTreeClassifier'> ExtraTreeClassifier
# <class 'sklearn.ensemble.forest.ExtraTreesClassifier'> ExtraTreesClassifier
# <class 'sklearn.naive_bayes.GaussianNB'> GaussianNB
# <class 'sklearn.gaussian_process.gpc.GaussianProcessClassifier'> GaussianProcessClassifier
# <class 'sklearn.ensemble.gradient_boosting.GradientBoostingClassifier'> GradientBoostingClassifier
# ...

# %%
import inspect
from sklearn.utils.testing import all_estimators
for name, clf in all_estimators(type_filter='classifier'):
    if 'sample_weight' in inspect.getargspec(clf().fit)[0]:
       print(name)
# Out:
# AdaBoostClassifier
# BaggingClassifier
# BernoulliNB
# CalibratedClassifierCV
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-01d4d1635380> in <module>
#       2 from sklearn.utils.testing import all_estimators
#       3 for name, clf in all_estimators(type_filter='classifier'):
# ----> 4     if 'sample_weight' in inspect.getargspec(clf().fit)[0]:
#       5        print(name)
#
# TypeError: __init__() missing 1 required positional argument: 'base_estimator'

# %%
from sklearn.utils.testing import all_estimators
all_est = all_estimators(type_filter=None)
all_classifiers = all_estimators(type_filter="classifier")

# %%
import inspect
all_classifiers_fit_args = {}
for name, clf in all_classifiers:
    all_classifiers_fit_args[name] = inspect.signature(clf.fit)

# %%
df = pd.DataFrame(all_classifiers_fit_args.items(), columns=["fit_classifier", "args"])
df
# Out:
#                     fit_classifier  \
# 0               AdaBoostClassifier
# 1                BaggingClassifier
# 2                      BernoulliNB
# 3           CalibratedClassifierCV
# 4               CheckingClassifier
# 5                  ClassifierChain
# 6                     ComplementNB
# 7           DecisionTreeClassifier
# 8                  DummyClassifier
# 9              ExtraTreeClassifier
# 10            ExtraTreesClassifier
# 11                      GaussianNB
# 12       GaussianProcessClassifier
# 13      GradientBoostingClassifier
# 14  HistGradientBoostingClassifier
# 15            KNeighborsClassifier
# 16                LabelPropagation
# 17                  LabelSpreading
# 18      LinearDiscriminantAnalysis
# 19                       LinearSVC
# 20              LogisticRegression
# 21            LogisticRegressionCV
# 22                   MLPClassifier
# 23           MultiOutputClassifier
# 24                   MultinomialNB
# ...

# %%
from scipy.sparse import csc_matrix
from sklearn.utils.testing import all_estimators
import numpy as np
import random

for name, Clf in all_estimators(type_filter='classifier'):
    try:
        clf = Clf()
        clf.fit(X_train,y_train)
        print (name)
    except:
        pass
# Out:
# AdaBoostClassifier
# BaggingClassifier
# BernoulliNB
# CalibratedClassifierCV
# CheckingClassifier
# DecisionTreeClassifier
# DummyClassifier
# ExtraTreeClassifier
# ExtraTreesClassifier
# GaussianNB
# GradientBoostingClassifier
# HistGradientBoostingClassifier
# KNeighborsClassifier
# LinearDiscriminantAnalysis
# LinearSVC
# LogisticRegression
# LogisticRegressionCV
# MLPClassifier
# NearestCentroid

# %%
y_pred = clf.predict(X_test)
print(name, "의 정확도 : ", accuracy_score(y_test,y_pred))
