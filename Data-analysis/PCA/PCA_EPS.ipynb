# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame as df
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import cross_val_score    
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
data1_1 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/test_data/LR1.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data1_2 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/test_data/LR2.csv',names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data1_3 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/test_data/LR3.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])

data11 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/LR/2.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data12 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/LR/3.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data13 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/LR/4.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])

data2_1 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/test_data/RL1.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data2_2 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/test_data/RL2.csv',names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data2_3 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/test_data/RL3.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])

data21 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/RL/2.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data22 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/RL/3.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data23 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/RL/4.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])

data3_1 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/test_data/CW1.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data3_2 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/test_data/CW2.csv',names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data3_3 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/test_data/CW3.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])

data31 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/CW/2.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data32 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/CW/3.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data33 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/CW/4.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])

data4_1 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/test_data/CCW1.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data4_2 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/test_data/CCW2.csv',names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data4_3 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/test_data/CCW3.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])

data41 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/CCW/2.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data42 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/CCW/3.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data43 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/CCW/4.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])



data5_1 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/UP/2.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data5_2 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/UP/3.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data5_3 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/UP/4.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])

data6_1 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/DOWN/2.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data6_2 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/DOWN/3.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])
data6_3 = pd.read_csv('C:/Users/hml76/OneDrive/바탕 화면/Capacitive_sensor_research/new_datas/datas/DOWN/4.csv', names=['n','na','a','b','c','d','a-b','c-d','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'])

# %%
data1_1.d1 = 0
data1_2.d1 = 0
data1_3.d1 = 0

data11.d1=0
data12.d1=0
data13.d1=0

data2_1.d1 = 1
data2_2.d1 = 1
data2_3.d1 = 1

data21.d1=1
data22.d1=1
data23.d1=1

data3_1.d1 = 2
data3_2.d1 = 2
data3_3.d1 = 2

data31.d1=2
data32.d1=2
data33.d1=2

data4_1.d1 = 3
data4_2.d1 = 3
data4_3.d1 = 3

data41.d1=3
data42.d1=3
data43.d1=3

data5_1.d1 = 4
data5_2.d1 = 4
data5_3.d1 = 4

data6_1.d1 = 5
data6_2.d1 = 5
data6_3.d1 = 5

# %%
x1_1 = data1_1.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values # 독립변인들의 value값만 추출
x1_2 = data1_2.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x1_3 = data1_3.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 

x11 = data11.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values # 독립변인들의 value값만 추출
x12 = data12.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x13 = data13.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 

x2_1 = data2_1.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x2_2 = data2_2.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x2_3 = data2_3.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 

x21 = data21.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values # 독립변인들의 value값만 추출
x22 = data22.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x23 = data23.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 

x3_1 = data3_1.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x3_2 = data3_2.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x3_3 = data3_3.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values

x31 = data31.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x32 = data32.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x33 = data33.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values

x4_1 = data4_1.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x4_2 = data4_2.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x4_3 = data4_3.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 

x41 = data41.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x42 = data42.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x43 = data43.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 


x5_1 = data5_1.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x5_2 = data5_2.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x5_3 = data5_3.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 

x6_1 = data6_1.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x6_2 = data6_2.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values 
x6_3 = data6_3.drop(['n','na','d2','d3','d4','d5','d6','d7','d8','d9','d10','d11'], axis=1).values

# %%
x1_1 = pd.DataFrame(x1_1)
x1_2 = pd.DataFrame(x1_2)
x1_3 = pd.DataFrame(x1_3)
x2_1 = pd.DataFrame(x2_1)
x2_2 = pd.DataFrame(x2_2)
x2_3 = pd.DataFrame(x2_3)
x3_1 = pd.DataFrame(x3_1)
x3_2 = pd.DataFrame(x3_2)
x3_3 = pd.DataFrame(x3_3)
x4_1 = pd.DataFrame(x4_1)
x4_2 = pd.DataFrame(x4_2)
x4_3 = pd.DataFrame(x4_3)
x5_1 = pd.DataFrame(x5_1)
x5_2 = pd.DataFrame(x5_2)
x5_3 = pd.DataFrame(x5_3)
x6_1 = pd.DataFrame(x6_1)
x6_2 = pd.DataFrame(x6_2)
x6_3 = pd.DataFrame(x6_3)

x11 = pd.DataFrame(x11)
x12 = pd.DataFrame(x12)
x13 = pd.DataFrame(x13)
x21 = pd.DataFrame(x21)
x22 = pd.DataFrame(x22)
x23 = pd.DataFrame(x23)
x31 = pd.DataFrame(x31)
x32 = pd.DataFrame(x32)
x33 = pd.DataFrame(x33)
x41 = pd.DataFrame(x41)
x42 = pd.DataFrame(x42)
x43 = pd.DataFrame(x43)

# %%
total = x1_1.append(x1_2,ignore_index=True)
total = total.append(x1_3,ignore_index=True)
total = total.append(x2_1,ignore_index=True)
total = total.append(x2_2,ignore_index=True)
total = total.append(x2_3,ignore_index=True)
total = total.append(x3_1,ignore_index=True)
total = total.append(x3_2,ignore_index=True)
total = total.append(x3_3,ignore_index=True)
total = total.append(x4_1,ignore_index=True)
total = total.append(x4_2,ignore_index=True)
total = total.append(x4_3,ignore_index=True)
total = total.append(x5_1,ignore_index=True)
total = total.append(x5_2,ignore_index=True)
total = total.append(x5_3,ignore_index=True)
total = total.append(x6_1,ignore_index=True)
total = total.append(x6_2,ignore_index=True)
total = total.append(x6_3,ignore_index=True)


total_4 = x11.append(x12,ignore_index=True)
total_4 = total_4.append(x13,ignore_index=True)
total_4 = total_4.append(x21,ignore_index=True)
total_4 = total_4.append(x22,ignore_index=True)
total_4 = total_4.append(x23,ignore_index=True)
total_4 = total_4.append(x31,ignore_index=True)
total_4 = total_4.append(x32,ignore_index=True)
total_4 = total_4.append(x33,ignore_index=True)
total_4 = total_4.append(x41,ignore_index=True)
total_4 = total_4.append(x42,ignore_index=True)
total_4 = total_4.append(x43,ignore_index=True)

# %%
total.shape, total_4.shape
# Out:
# ((12600, 7), (5900, 7))

# %%
total_arr = np.array(total)
total_4_arr = np.array(total_4)

# %%
x = total_arr[:,0:6]
x_4 = total_4_arr[:,0:6]
y = total_arr[:,6]
y_4 = total_4_arr[:,6]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pc = pca.fit_transform(x_4)

# %%
pc_y = np.c_[pc,y_4]
df = pd.DataFrame(pc_y,columns=['PC1','PC2','diagnosis'])

# %%
plt.scatter(x=df['PC1'],y=df['PC2'],c=df['diagnosis'])

# %%
import seaborn as sns
sns.scatterplot(data=df,x='PC1',y='PC2',hue='diagnosis')

# %%
x_4
# Out:
# array([[ 0.14851 , -0.978114, -0.077965, -0.293526,  1.126624,  0.215561],
#        [ 0.1532  , -0.978047, -0.075233, -0.291499,  1.131247,  0.216266],
#        [ 0.158297, -0.97803 , -0.072494, -0.289853,  1.136327,  0.217359],
#        ...,
#        [-0.065546, -0.10909 , -0.089168, -0.051908,  0.043544, -0.037259],
#        [-0.0707  , -0.113911, -0.092849, -0.056244,  0.043211, -0.036605],
#        [-0.076533, -0.119026, -0.096886, -0.060989,  0.042493, -0.035897]])

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline

# Create scaler: scaler
# Create a PCA instance: pca
pca_1 = PCA()

# Create pipeline: pipeline
#pipeline = make_pipeline(scaler,pca_1)

# Fit the pipeline to 'samples'
pca_1.fit(x_4)

features = range(pca_1.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-f947b77dace4> in <module>
#      13
#      14 features = range(pca_1.n_components_)
# ---> 15 plt.bar(features, pca.explained_variance_)
#      16 plt.xlabel('PCA feature')
#      17 plt.ylabel('variance')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
# -> 2441         **({"data": data} if data is not None else {}), **kwargs)
#    2442
#    2443
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt

# Create scaler: scaler
scaler = StandardScaler()

# Create a PCA instance: pca
pca = PCA()

# Create pipeline: pipeline
pipeline = make_pipeline(scaler,pca)

# Fit the pipeline to 'samples'
pipeline.fit(x_4)

features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()

# %%
import numpy.linalg as linalg
from sklearn.preprocessing import StandardScaler
from sklearn import datasets

x_std = StandardScaler().fit_transform(x_4)

x_cov = (np.cov(x_std.T))
x_cov
# Out:
# array([[ 1.00016952, -0.05700675,  0.54167169,  0.4376102 ,  0.51011519,
#          0.27298048],
#        [-0.05700675,  1.00016952,  0.73114657,  0.79776505, -0.8879797 ,
#         -0.01940083],
#        [ 0.54167169,  0.73114657,  1.00016952,  0.87055904, -0.38025653,
#          0.38691655],
#        [ 0.4376102 ,  0.79776505,  0.87055904,  1.00016952, -0.48561646,
#         -0.11729397],
#        [ 0.51011519, -0.8879797 , -0.38025653, -0.48561646,  1.00016952,
#          0.14253773],
#        [ 0.27298048, -0.01940083,  0.38691655, -0.11729397,  0.14253773,
#          1.00016952]])

# %%
eig_vals, eig_vecs = np.linalg.eig(x_cov)
eig_vals_sum = np.sum(eig_vals)
for eig_val in eig_vals:
    print ("contain " + str(eig_val/eig_vals_sum))
# Out:
# contain 0.521708439294312
# contain 0.3120412129072281
# contain 0.15818488412325996
# contain 0.008065463674738513
# contain 1.1836849418208895e-13
# contain 3.430691938985557e-13

# %%
import numpy.linalg as linalg
from sklearn.preprocessing import StandardScaler
from sklearn import datasets


x_cov = (np.cov(x_4.T))
x_cov
# Out:
# array([[ 0.03866293, -0.00411912,  0.02598977,  0.0194966 ,  0.04278205,
#          0.00649317],
#        [-0.00411912,  0.1350853 ,  0.06557336,  0.06643594, -0.13920441,
#         -0.00086259],
#        [ 0.02598977,  0.06557336,  0.05956417,  0.04814097, -0.03958359,
#          0.0114232 ],
#        [ 0.0194966 ,  0.06643594,  0.04814097,  0.05135649, -0.04693934,
#         -0.00321552],
#        [ 0.04278205, -0.13920441, -0.03958359, -0.04693934,  0.18198646,
#          0.00735576],
#        [ 0.00649317, -0.00086259,  0.0114232 , -0.00321552,  0.00735576,
#          0.01463872]])

# %%
eig_vals, eig_vecs = np.linalg.eig(x_cov)
eig_vals_sum = np.sum(eig_vals)
for eig_val in eig_vals:
    print ("contain " + str(eig_val/eig_vals_sum))
# Out:
# contain 0.7239699898310524
# contain 0.22840202728880388
# contain 0.041333379600703345
# contain 0.006294603279086526
# contain 1.7484808039454695e-13
# contain 1.7901831193123218e-13

# %%
pca.explained_variance_ratio_
#sum(pca.explained_variance_ratio_)
# Out:
# array([5.21708439e-01, 3.12041213e-01, 1.58184884e-01, 8.06546367e-03,
#        3.43089658e-13, 1.18294496e-13])

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

model = PCA(n_components=1)
pca_features = model.fit_transform(x_4)

xf = pca_features[:,0]
yf = len(xf)*[0]
plt.scatter(xf,yf,c=y_4);
plt.show();

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

model = PCA(n_components=2)
pca_features = model.fit_transform(x_4)

pca_features

xf = pca_features[:,0]
yf = pca_features[:,1]
plt.scatter(xf,yf,c=y_4);
plt.show();

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

model = PCA(n_components=3)
pca_features = model.fit_transform(x_4)

pca_features

xf = pca_features[:,0]
yf = pca_features[:,1]
zf = pca_features[:,2]
plt.scatter(xf,yf,zf,c=y_4);
plt.show();
# Out:
# C:\Users\hml76\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
s = pd.DataFrame(pca_features)
s
# Out:
#              0         1         2
# 0     1.133528 -0.691959  0.162571
# 1     1.135585 -0.699065  0.162341
# 2     1.138118 -0.706499  0.162535
# 3     1.141341 -0.713161  0.163192
# 4     1.145434 -0.718083  0.164343
# ...        ...       ...       ...
# 5895 -0.223604 -0.265190 -0.069557
# 5896 -0.221686 -0.263145 -0.068602
# 5897 -0.217951 -0.257977 -0.067127
# 5898 -0.213263 -0.250644 -0.065268
# 5899 -0.208480 -0.242365 -0.063200
#
# [5900 rows x 3 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(xf,yf,zf,c=y_4)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(yf,xf,zf,c=y_4)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(zf,yf,xf,c=y_4)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(xf,yf,c=y_4)
ax.set_xlabel('a')
ax.set_ylabel('b')
ax.set_zlabel('c')
plt.show()
